# %%
from matplotlib import pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# Reading the data set
df = pd.read_csv(r'dataset/H1_nav.csv',  encoding = 'utf8')
# Setting number of points for vizualization

df = df.iloc[:,1:]

print(df)
xyz = df.iloc[:,0:3]

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(xyz.iloc[:,0]*10, xyz.iloc[:,1], xyz.iloc[:,2], c=xyz.iloc[:,2]);
# Out:
#            x       y       z   HMDRX     HMDRY     HMDRZ Participant Dataset  \
# 0     0.0500  1.7868 -1.0947  6.9163  350.8206  359.9912      P01_V1      H1
# 1     0.0498  1.7871 -1.0951  6.9116  351.1272    0.0094      P01_V1      H1
# 2     0.0498  1.7872 -1.0955  6.8915  351.3081    0.0221      P01_V1      H1
# 3     0.0498  1.7870 -1.0961  6.9375  351.5385  359.9731      P01_V1      H1
# 4     0.0497  1.7865 -1.0969  7.1456  351.7421  359.8803      P01_V1      H1
# ...      ...     ...     ...     ...       ...       ...         ...     ...
# 9511 -0.0306  1.8041 -0.9720  6.7797    1.2876  355.3374      P27_V1      H1
# 9512 -0.0304  1.8041 -0.9725  6.7526    1.2680  355.3192      P27_V1      H1
# 9513 -0.0302  1.8041 -0.9727  6.7341    1.2694  355.3110      P27_V1      H1
# 9514 -0.0300  1.8041 -0.9731  6.7192    1.2976  355.3169      P27_V1      H1
# 9515 -0.0299  1.8041 -0.9732  6.7142    1.3088  355.3220      P27_V1      H1
#
#       ViewFrame
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
# ...         ...
# 9511        193
# 9512        194
# 9513        195
# 9514        196
# 9515        197
#
# [9516 rows x 9 columns]
